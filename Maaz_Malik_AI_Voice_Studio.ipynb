# %% [markdown]
# <a href="https://colab.research.google.com/github/maazmalik-ai/Maaz-Malik-Voice-Studio/blob/main/Maaz_Malik_AI_Voice_Studio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 🎙️ Maaz Malik AI Voice Studio — Enterprise Launch { display-mode: "form" }

#@markdown ### ⚡ Quick Launch Guide:
#@markdown 1. **Enter Email:** Type your registered license email below.
#@markdown 2. **Run:** Click the **Play (Run)** button. Link generation status will update in the banner below automatically.
#@markdown 3. **Launch:** Once generated, click the **"Open Enterprise Studio Dashboard"** button to start.

EMAIL = 'maaz.malik0684@gmail.com' #@param {type:"string"}

import os, sys, re, json, urllib.request, urllib.parse, time
from IPython.display import clear_output, display, HTML

em = EMAIL.strip().lower()
api_url = 'https://script.google.com/macros/s/AKfycbz11Cc2q-j4pYWYMXbPW5OW5sMoIjyDPv1mhm6mrHlZeqOHs-kwrdMamvQ2T4G3GWAuzQ/exec'
secret_key = 'maaz_secure_key_2026'

def render_ui_card(state="loading", public_url="", error_msg=""):
    clear_output()

    if state == "error":
        display(HTML(f"""
        <div style="font-family:-apple-system,BlinkMacSystemFont,'Segoe UI',Roboto,Helvetica,sans-serif;
                    background:linear-gradient(135deg, #180914 0%, #0d040c 100%);
                    border:1.5px solid rgba(244,63,94,0.5);border-radius:24px;padding:32px 38px;max-width:820px;
                    box-shadow: 0 20px 50px rgba(0,0,0,0.6), 0 0 30px rgba(244,63,94,0.25), inset 0 1px 0 rgba(255,255,255,0.1);
                    margin:12px 0;transform: perspective(1000px) rotateX(1deg);">
            <div style="display:flex;justify-content:space-between;align-items:center;flex-wrap:wrap;gap:12px;margin-bottom:14px;">
                <div style="font-size:1.65em;font-weight:900;color:#ffffff;letter-spacing:-0.5px;text-shadow: 0 2px 4px rgba(0,0,0,0.5);">
                    🎙️ Maaz Malik AI Voice Studio
                </div>
                <span style="background:rgba(244,63,94,0.2);border:1px solid #f43f5e;color:#fb7185;font-size:11.5px;font-weight:800;padding:6px 14px;border-radius:20px;box-shadow: 0 4px 12px rgba(244,63,94,0.3);">
                    ● ACCESS DENIED / CANCELLED
                </span>
            </div>
            <p style="color:#fecdd3;font-size:14.5px;line-height:1.6;margin:0 0 20px 0;">
                {error_msg}
            </p>
            <div style="border-top:1px solid rgba(244,63,94,0.25);padding-top:18px;margin-top:12px;">
                <div style="color:#ffffff;font-size:13.5px;font-weight:700;margin-bottom:14px;letter-spacing:0.3px;">
                    Please contact admin for license activation & support:
                </div>
                <div style="display:flex;align-items:center;gap:14px;flex-wrap:wrap;">
                    <a href="https://wa.me/923328140684" target="_blank" style="display:inline-flex;align-items:center;gap:8px;background:linear-gradient(135deg,#2ecc71,#27ae60);color:#ffffff;font-weight:900;font-size:14px;text-decoration:none;padding:13px 30px;border-radius:12px;box-shadow: 0 8px 20px rgba(39,174,96,0.4), inset 0 1px 0 rgba(255,255,255,0.3);transition: all 0.2s;">
                        💬 WhatsApp: 0332-8140684
                    </a>
                    <a href="https://www.instagram.com/maaz.rigs" target="_blank" style="display:inline-flex;align-items:center;gap:8px;background:linear-gradient(135deg,#e1306c,#c13584);color:#fff;font-weight:900;font-size:14px;text-decoration:none;padding:13px 30px;border-radius:12px;box-shadow: 0 8px 20px rgba(193,53,132,0.4), inset 0 1px 0 rgba(255,255,255,0.3);transition: all 0.2s;">
                        📸 Instagram: @maaz.rigs
                    </a>
                </div>
            </div>
        </div>
        """))
        return

    is_ready = (state == "ready")

    badge = '''
    <span style="background:rgba(16,185,129,0.2);border:1px solid #10b981;color:#6ee7b7;font-size:11.5px;font-weight:800;padding:6px 14px;border-radius:20px;box-shadow: 0 4px 12px rgba(16,185,129,0.3);">
        ● STUDIO READY
    </span>
    ''' if is_ready else '''
    <span style="background:rgba(0,212,255,0.2);border:1px solid #00d4ff;color:#38bdf8;font-size:11.5px;font-weight:800;padding:6px 14px;border-radius:20px;box-shadow: 0 4px 12px rgba(0,212,255,0.3);">
        ⚙️ GENERATING LINK...
    </span>
    '''

    action_button = f'''
    <div style="margin:24px 0 18px;display:flex;align-items:center;gap:16px;flex-wrap:wrap;">
        <a href="{public_url}" target="_blank" style="display:inline-flex;align-items:center;gap:10px;background:linear-gradient(135deg,#00d4ff,#0077b6);color:#04111d;font-weight:900;font-size:16px;text-decoration:none;padding:15px 38px;border-radius:14px;box-shadow: 0 10px 30px rgba(0,212,255,0.45), inset 0 2px 0 rgba(255,255,255,0.4);letter-spacing:0.3px;transition: all 0.2s;">
            🚀 Open Enterprise Studio Dashboard
        </a>
        <a href="{public_url}" target="_blank" style="color:#38bdf8;font-family:monospace;font-size:13px;background:rgba(15,23,42,0.9);padding:11px 18px;border-radius:10px;border:1px solid rgba(0,212,255,0.3);text-decoration:underline;box-shadow: 0 4px 15px rgba(0,0,0,0.5);">
            {public_url}
        </a>
    </div>
    ''' if is_ready else '''
    <div style="margin:22px 0 16px;display:flex;align-items:center;gap:14px;">
        <div style="width:16px;height:16px;border:3px solid #00d4ff;border-top-color:transparent;border-radius:50%;animation:spin 0.8s linear infinite;"></div>
        <span style="color:#38bdf8;font-weight:700;font-size:14.5px;text-shadow: 0 2px 4px rgba(0,0,0,0.5);">Secure link is generating... Please wait while T4 GPU initializes.</span>
    </div>
    '''

    display(HTML(f"""
    <style>
        @keyframes spin {{ 100% {{ transform: rotate(360deg); }} }}
    </style>
    <div style="font-family:-apple-system,BlinkMacSystemFont,'Segoe UI',Roboto,Helvetica,sans-serif;
                background:linear-gradient(145deg, #0a192f 0%, #060e1a 60%, #03070f 100%);
                border:1.5px solid rgba(0,212,255,0.5);border-radius:24px;padding:32px 38px;max-width:840px;
                box-shadow: 0 20px 60px rgba(0,0,0,0.7), 0 0 35px rgba(0,212,255,0.25), inset 0 1px 0 rgba(255,255,255,0.15);
                margin:12px 0;transform: perspective(1000px) rotateX(1deg);">

        <div style="display:flex;justify-content:space-between;align-items:center;flex-wrap:wrap;gap:12px;margin-bottom:14px;">
            <div style="font-size:1.7em;font-weight:900;color:#ffffff;letter-spacing:-0.5px;text-shadow: 0 2px 4px rgba(0,0,0,0.5);">
                🎙️ Maaz Malik AI Voice Studio <span style="color:#00d4ff;font-size:15px;font-weight:700;">(Enterprise v2.6)</span>
            </div>
            {badge}
        </div>

        <p style="color:#94a3b8;font-size:14.5px;line-height:1.6;margin:0 0 22px 0;text-shadow: 0 1px 2px rgba(0,0,0,0.5);">
            High-Performance Audio Suite optimized for instant clone generation, fast MP3 rendering, and zero-token usage.
        </p>

        {action_button}

        <div style="display:grid;grid-template-columns:repeat(auto-fit, minmax(180px, 1fr));gap:14px;margin:24px 0;">
            <div style="background:linear-gradient(145deg, rgba(15,32,56,0.9), rgba(10,22,39,0.9));border:1px solid rgba(0,212,255,0.3);border-radius:14px;padding:16px;box-shadow: 0 8px 20px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.08);">
                <div style="color:#00d4ff;font-size:12px;font-weight:800;text-transform:uppercase;letter-spacing:0.5px;">Voice Cloning</div>
                <div style="color:#f1f5f9;font-size:14px;font-weight:700;margin-top:4px;">Multi-Accent Cloner</div>
                <div style="color:#64748b;font-size:12px;margin-top:2px;">Instant 3s voice match</div>
            </div>
            <div style="background:linear-gradient(145deg, rgba(15,32,56,0.9), rgba(10,22,39,0.9));border:1px solid rgba(0,212,255,0.3);border-radius:14px;padding:16px;box-shadow: 0 8px 20px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.08);">
                <div style="color:#00d4ff;font-size:12px;font-weight:800;text-transform:uppercase;letter-spacing:0.5px;">FX Mastering</div>
                <div style="color:#f1f5f9;font-size:14px;font-weight:700;margin-top:4px;">50+ Studio Presets</div>
                <div style="color:#64748b;font-size:12px;margin-top:2px;">SM7B, Echo, Monster, Lo-Fi</div>
            </div>
            <div style="background:linear-gradient(145deg, rgba(15,32,56,0.9), rgba(10,22,39,0.9));border:1px solid rgba(0,212,255,0.3);border-radius:14px;padding:16px;box-shadow: 0 8px 20px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.08);">
                <div style="color:#00d4ff;font-size:12px;font-weight:800;text-transform:uppercase;letter-spacing:0.5px;">CapCut Editor</div>
                <div style="color:#f1f5f9;font-size:14px;font-weight:700;margin-top:4px;">Timeline Razor Cut</div>
                <div style="color:#64748b;font-size:12px;margin-top:2px;">MM:SS precise clip export</div>
            </div>
            <div style="background:linear-gradient(145deg, rgba(15,32,56,0.9), rgba(10,22,39,0.9));border:1px solid rgba(0,212,255,0.3);border-radius:14px;padding:16px;box-shadow: 0 8px 20px rgba(0,0,0,0.5), inset 0 1px 0 rgba(255,255,255,0.08);">
                <div style="color:#00d4ff;font-size:12px;font-weight:800;text-transform:uppercase;letter-spacing:0.5px;">Audio Quality</div>
                <div style="color:#f1f5f9;font-size:14px;font-weight:700;margin-top:4px;">320k Studio Normalizer</div>
                <div style="color:#64748b;font-size:12px;margin-top:2px;">Auto Noise Reduction</div>
            </div>
        </div>

        <div style="border-top:1px solid rgba(255,255,255,0.1);padding-top:16px;display:flex;justify-content:space-between;align-items:center;flex-wrap:wrap;gap:12px;font-size:12.5px;color:#94a3b8;">
            <div style="display:flex;gap:16px;flex-wrap:wrap;">
                <span>📸 Support: <a href="https://instagram.com/maaz.rigs" target="_blank" style="color:#38bdf8;text-decoration:none;font-weight:700;">@maaz.rigs</a></span>
                <span>💬 WhatsApp: <b style="color:#22c55e;">0332-8140684</b></span>
            </div>
            <span style="color:#38bdf8;font-weight:600;">🔒 Official License Protected</span>
        </div>
    </div>
    """))

render_ui_card("loading")

def halt_execution():
    import sys
    sys.exit(0)

if not em:
    render_ui_card("error", error_msg="Authentication Failed: The email field cannot be empty. Please enter your registered license email.")
    halt_execution()

colab_email = ''
try:
    from google.colab import auth
    auth.authenticate_user()
    import google.auth, google.auth.transport.requests
    creds, _ = google.auth.default()
    creds.refresh(google.auth.transport.requests.Request())
    token = creds.token
    req = urllib.request.Request(
        f'https://www.googleapis.com/oauth2/v1/userinfo?access_token={token}',
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    with urllib.request.urlopen(req, timeout=10) as r:
        info = json.loads(r.read().decode())
    colab_email = info.get('email', '').lower()
except Exception:
    render_ui_card("error", error_msg="Authentication Cancelled: You must click 'Allow' or 'Continue' on the Google credentials prompt to verify your account and generate the studio link.")
    halt_execution()

if not colab_email:
    render_ui_card("error", error_msg="Authentication Cancelled: Permission to access Google credentials was denied. Studio link generation halted.")
    halt_execution()

if colab_email != em:
    render_ui_card("error", error_msg=f"Account Mismatch: Your signed-in Google Colab account (<b>{colab_email}</b>) does not match the entered license email (<b>{em}</b>).")
    halt_execution()

try:
    req = urllib.request.Request(
        f'{api_url}?key={secret_key}&email={urllib.parse.quote(em)}',
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    with urllib.request.urlopen(req, timeout=15) as r:
        data = json.loads(r.read().decode())
    status = data.get('status', '')
    if status != 'ok':
        render_ui_card("error", error_msg="Access Denied: This account is unregistered or your license key has expired.")
        halt_execution()
except Exception:
    pass

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
os.environ['GRADIO_ANALYTICS_ENABLED'] = 'False'
os.environ['PYTHONWARNINGS'] = 'ignore'

try:
    import torch
    if torch.cuda.is_available():
        torch.backends.cudnn.benchmark = True
        torch.backends.cuda.matmul.allow_tf32 = True
    else:
        render_ui_card("error", error_msg="Hardware Error: T4 GPU is not active. Go to Runtime > Change runtime type > T4 GPU and re-run.")
        halt_execution()
except ImportError:
    pass

os.chdir('/content')
if not os.path.exists('/content/voice-suite-colab'):
    get_ipython().system('git clone -q https://github.com/NeuralFalconYT/omnivoice-colab.git voice-suite-colab')
    os.chdir('/content/voice-suite-colab')
    get_ipython().system('git clone -q https://github.com/NeuralFalconYT/OmniVoice.git')
    get_ipython().system('pip install -q -r colab.txt')
    get_ipython().system('pip install -q pydub noisereduce soundfile librosa huggingface_hub scipy accelerate')
else:
    os.chdir('/content/voice-suite-colab')
    get_ipython().system('pkill -f "python app.py" || true')
    get_ipython().system('git checkout app.py > /dev/null 2>&1')
    if not os.path.exists('/content/voice-suite-colab/OmniVoice'):
        get_ipython().system('git clone -q https://github.com/NeuralFalconYT/OmniVoice.git')

if os.path.exists('/content/voice-suite-colab/OmniVoice/omnivoice'):
    get_ipython().system('cp -r /content/voice-suite-colab/OmniVoice/omnivoice /content/voice-suite-colab/')

tools_code = '''
import tempfile, uuid, os, sys
import noisereduce as nr
import soundfile as sf
import numpy as np
from scipy.signal import butter, lfilter
from pydub import AudioSegment

sys.path.append('/content/voice-suite-colab')
sys.path.append('/content/voice-suite-colab/OmniVoice')

PRESETS_50 = [
    "🎙️ Studio Condenser Mic Pro", "📻 Vintage Radio Broadcaster", "🎧 Podcast Warm Vocal", "🏰 Cathedral Reverb Chamber",
    "🌌 Deep Space Echo Cave", "📱 90s Nokia Phone Call", "🤖 Cyber Android Robot", "📻 Walkie Talkie Comms",
    "🔊 808 Deep Sub-Bass Booster", "📢 Megaphone Riot Announcement", "⚡ Telephone Bandpass", "📼 Lo-Fi Cassette Tape Warmth",
    "🛸 Alien Sci-Fi Transmitter", "👻 Dark Cinematic Ghost", "🎧 ASMR Ultra Crisp Intimate", "📻 AM Radio Distortion",
    "🎤 Stage Live Concert Hall", "🏟️ Stadium PA Speaker", "🚁 Helicopter Pilot Headset", "🌊 Underwater Resonance",
    "📀 Vinyl Record 1950s Gramophone", "🚗 Car Stereo Bass Boost", "📺 1980s VHS Tracking Tape", "🎤 FM Radio DJ Host",
    "🏢 Empty Warehouse Echo", "🚪 Locked Room Muffled Vocal", "🎙️ High-End Ribbon Warmth", "🤖 8-Bit Chiptune Arcade",
    "🌌 Cosmic Astral Modulation", "📻 Shortwave Military Radio", "🔊 Hyper Treble Air Boost", "🎛️ Tube Preamp Saturation",
    "🎤 Dynamic Shure SM7B Emulation", "🎙️ Neumann U87 Polish", "📻 Police Dispatch Scanner", "🗣️ Pitch Down Monster Titan",
    "🧚 Pitch Up Chipmunk Fairy", "🎧 Binaural 3D Surround Room", "📼 Degraded Analog Tape Flanging", "⚡ High Voltage Electric Vocal",
    "🏛️ Marble Hall Acoustic Reverb", "🚀 Astronaut Lunar Transmission", "🎤 Club DJ Auto-Filter Sweep", "🔊 Cinematic Sub Boom",
    "🤖 Vocoder Robotic Synth", "🎙️ Vocal Doubler Stereo Spreader", "📻 Distant Echo Chamber", "🎧 Crisp Voiceover Master",
    "📼 4-Track Cassette Bounce", "🌌 Interstellar Wormhole FX"
]

def fast_save_mp3(data, sr, prefix="audio"):
    tmp_path = os.path.join(tempfile.gettempdir(), f"{prefix}_{uuid.uuid4().hex[:8]}.mp3")
    wav_path = tmp_path.replace('.mp3', '.wav')
    sf.write(wav_path, data, sr, subtype='PCM_16')
    try:
        AudioSegment.from_wav(wav_path).export(tmp_path, format='mp3', bitrate='192k', parameters=["-q:a", "2"])
        if os.path.exists(wav_path):
            os.remove(wav_path)
        return tmp_path
    except Exception:
        return wav_path

def capcut_split_ui(audio_input, start_min, start_sec, end_min, end_sec):
    if audio_input is None:
        return None, None, "⚠️ Pehle audio import karein."
    try:
        sr, y = audio_input
        if len(y.shape) > 1:
            y = np.mean(y, axis=1)

        total_start = (float(start_min) * 60.0) + float(start_sec)
        total_end = (float(end_min) * 60.0) + float(end_sec)

        s_idx = max(0, int(total_start * sr))
        e_idx = min(len(y), int(total_end * sr)) if total_end > 0 else len(y)

        if s_idx >= e_idx:
            return None, None, f"⚠️ Start Point ({int(start_min):02d}:{float(start_sec):04.1f}) End Point ({int(end_min):02d}:{float(end_sec):04.1f}) se pehle hona chahiye!"

        trimmed = y[s_idx:e_idx]
        max_v = np.max(np.abs(trimmed))
        if max_v > 0:
            trimmed = (trimmed / max_v) * 0.95
        out_v = (trimmed * 32767).astype(np.int16)

        tmp_mp3 = fast_save_mp3(out_v, sr, "capcut_clip")
        clip_len = round((e_idx - s_idx)/sr, 2)
        return (sr, out_v), tmp_mp3, f"✅ Timeline Slice Exported! Duration: {clip_len}s"
    except Exception as e:
        return None, None, f"Error: {str(e)}"

def apply_fx_preset_ui(audio_input, preset_name, intensity):
    if audio_input is None:
        return None, None, "⚠️ Audio file provide karein."
    try:
        sr, y = audio_input
        y = y.astype(np.float32)
        if len(y.shape) > 1:
            y = np.mean(y, axis=1)

        y = y / (np.max(np.abs(y)) + 1e-6)
        mod = float(intensity)

        if "Monster" in preset_name or "Titan" in preset_name or "Dark Cinematic" in preset_name:
            factor = 0.65
            idx = np.round(np.arange(0, len(y), factor)).astype(int)
            idx = idx[idx < len(y)]
            y = y[idx]
            b, a = butter(2, 400 / (sr / 2), btype='low')
            low = lfilter(b, a, y)
            y = y + (low * 0.8 * mod)

        elif "Chipmunk" in preset_name or "Fairy" in preset_name:
            factor = 1.6
            idx = np.round(np.arange(0, len(y), factor)).astype(int)
            idx = idx[idx < len(y)]
            y = y[idx]

        elif "Robot" in preset_name or "Vocoder" in preset_name or "Android" in preset_name or "Alien" in preset_name or "8-Bit" in preset_name:
            t = np.arange(len(y)) / float(sr)
            carrier = np.sin(2 * np.pi * 140 * t)
            ring_mod = y * carrier * 2.5
            y = (1.0 - mod) * y + mod * ring_mod

        elif "Radio" in preset_name or "Walkie" in preset_name or "Police" in preset_name or "Scanner" in preset_name:
            b, a = butter(4, [600 / (sr / 2), 2400 / (sr / 2)], btype='band')
            filtered = lfilter(b, a, y)
            distortion = np.clip(filtered * 3.0, -0.6, 0.6)
            y = (1.0 - mod) * y + mod * (distortion * 1.4)

        elif "Phone" in preset_name or "Telephone" in preset_name:
            b, a = butter(4, [450 / (sr / 2), 2700 / (sr / 2)], btype='band')
            filtered = lfilter(b, a, y)
            distortion = np.tanh(filtered * 2.5)
            y = (1.0 - mod) * y + mod * distortion

        elif "Megaphone" in preset_name or "PA Speaker" in preset_name:
            b, a = butter(4, [700 / (sr / 2), 3500 / (sr / 2)], btype='band')
            filtered = lfilter(b, a, y)
            distortion = np.clip(filtered * 4.0, -0.5, 0.5)
            y = (1.0 - mod) * y + mod * (distortion * 1.5)

        elif "Cathedral" in preset_name or "Cave" in preset_name or "Warehouse" in preset_name or "Echo" in preset_name or "Reverb" in preset_name or "Hall" in preset_name:
            delays = [int(sr * 0.08), int(sr * 0.16), int(sr * 0.28)]
            echo = np.zeros(len(y) + delays[-1])
            echo[:len(y)] += y
            for idx, d in enumerate(delays):
                echo[d:d+len(y)] += y * ((0.5 / (idx + 1)) * mod)
            y = echo[:len(y)]

        elif "Bass" in preset_name or "Sub" in preset_name or "808" in preset_name or "Car Stereo" in preset_name:
            b, a = butter(2, 220 / (sr / 2), btype='low')
            y = y + (lfilter(b, a, y) * mod * 2.5)

        elif "Underwater" in preset_name or "Muffled" in preset_name or "Locked Room" in preset_name:
            b, a = butter(4, 500 / (sr / 2), btype='low')
            y = lfilter(b, a, y) * 1.8

        elif "Studio" in preset_name or "Neumann" in preset_name or "Shure" in preset_name or "Ribbon" in preset_name or "Podcast" in preset_name or "Master" in preset_name:
            b, a = butter(2, 75 / (sr / 2), btype='high')
            y = lfilter(b, a, y)
            b2, a2 = butter(2, 3800 / (sr / 2), btype='high')
            y = y + (lfilter(b2, a2, y) * 0.45 * mod)
        else:
            b, a = butter(2, 100 / (sr / 2), btype='high')
            y = lfilter(b, a, y)

        y = (y / (np.max(np.abs(y)) + 1e-6)) * 0.95
        out_v = (y * 32767).astype(np.int16)

        tmp_mp3 = fast_save_mp3(out_v, sr, "fx")
        return (sr, out_v), tmp_mp3, f"✅ Preset Applied: {preset_name}"
    except Exception as e:
        return None, None, f"Error: {str(e)}"

def clean_audio_ui(audio_input, strength):
    if audio_input is None:
        return None, None, "⚠️ Audio file provide karein."
    try:
        sr, y = audio_input
        y = y.astype(np.float32)
        if len(y.shape) > 1:
            y = np.mean(y, axis=1)
        max_v = np.max(np.abs(y))
        if max_v > 0:
            y = y / max_v
        reduced = nr.reduce_noise(y=y, sr=sr, prop_decrease=float(strength), stationary=True)
        out_v = (reduced * 32767).astype(np.int16)

        tmp_mp3 = fast_save_mp3(out_v, sr, "clean")
        return (sr, out_v), tmp_mp3, "✅ Background Noise Completely Removed!"
    except Exception as e:
        return None, None, f"Error: {str(e)}"

def convert_to_mp3(wav_path):
    if not wav_path or not os.path.exists(wav_path):
        return wav_path
    try:
        mp3_path = wav_path.rsplit('.', 1)[0] + '.mp3'
        AudioSegment.from_wav(wav_path).export(mp3_path, format='mp3', bitrate='192k', parameters=["-q:a", "2"])
        return mp3_path
    except Exception:
        return wav_path
'''

dashboard_tab = '''
    gr.HTML("""
        <style>
            footer, .footer, div[class*="footer"], .show-api, .built-with, a[href*="gradio.app"], button[aria-label="Settings"] {
                display: none !important;
            }
            :root {
                --body-background-fill: #050b14;
                --block-background-fill: rgba(10, 22, 40, 0.75);
                --block-border-color: rgba(0, 212, 255, 0.25);
            }
            body, .gradio-container, gradio-app {
                background: radial-gradient(circle at 50% 0%, #0c2340 0%, #050b14 70%) !important;
                background-attachment: fixed !important;
                font-family: system-ui, -apple-system, Roboto, sans-serif !important;
                color: #e2e8f0 !important;
            }
            .block, .form, .gr-box, .panel, .gr-group {
                background: rgba(10, 22, 40, 0.7) !important;
                backdrop-filter: blur(12px) !important;
                border: 1px solid rgba(0, 212, 255, 0.22) !important;
                border-radius: 16px !important;
            }
            textarea, input[type='text'], input[type='number'], select {
                background: rgba(15, 34, 61, 0.8) !important;
                color: #f8fafc !important;
                border: 1px solid rgba(0, 212, 255, 0.3) !important;
                border-radius: 10px !important;
            }
            button.primary {
                background: linear-gradient(135deg, #0077b6, #00d4ff) !important;
                color: #ffffff !important;
                border: none !important;
                font-weight: 700 !important;
                border-radius: 10px !important;
                box-shadow: 0 4px 18px rgba(0, 212, 255, 0.35) !important;
            }
            .tab-nav button { font-size: 13.5px !important; padding: 10px 18px !important; font-weight: 600 !important; }
            .tabs { flex-wrap: nowrap !important; }
        </style>
        <div style="background: radial-gradient(circle at center, #0f2b4c 0%, #081526 100%); border: 1.5px solid #00d4ff; border-radius: 16px; padding: 22px; text-align: center; margin-bottom: 16px; box-shadow: 0 4px 25px rgba(0, 212, 255, 0.25);">
            <h1 style="color: #00d4ff; margin: 0 0 6px 0; font-size: 27px; font-weight: 900; letter-spacing: 0.5px;">🎙️ MAAZ MALIK ENTERPRISE VOICE STUDIO</h1>
            <p style="color: #cbd5e1; margin: 0 0 14px 0; font-size: 13px; font-weight: 500;">Next-Gen Multi-Engine Voice Suite — CapCut Timeline Cutter, 50+ FX Presets & Fast Mastering</p>
            <div style="display: inline-block; background: linear-gradient(45deg, #0077b6, #00d4ff); color: #000; font-size: 12px; font-weight: 800; padding: 7px 22px; border-radius: 20px; box-shadow: 0 4px 15px rgba(0, 212, 255, 0.35);">
                📸 Official Instagram Support: <a href='https://www.instagram.com/maaz.rigs' target='_blank' style='color:#000; text-decoration:none;'>@maaz.rigs</a>
            </div>
        </div>
    """)
    with gr.Tabs():
        with gr.TabItem("📊 Dashboard"):
            gr.HTML("""
                <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 15px; margin-bottom: 25px;">
                    <div style="background: rgba(12, 24, 43, 0.85); border: 1px solid #00d4ff; border-radius: 14px; padding: 20px; text-align: center;">
                        <span style="font-size: 28px;">⚡</span>
                        <h4 style="margin: 8px 0 4px 0; color: #00d4ff; font-weight: bold; font-size: 15px;">Turbo GPU Engine</h4>
                        <p style="margin: 0; font-size: 13px; color: #10b981; font-weight: bold;">● Active (High-Throughput)</p>
                    </div>
                    <div style="background: rgba(12, 24, 43, 0.85); border: 1px solid #00d4ff; border-radius: 14px; padding: 20px; text-align: center;">
                        <span style="font-size: 28px;">🎙️</span>
                        <h4 style="margin: 8px 0 4px 0; color: #00d4ff; font-weight: bold; font-size: 15px;">Voice Suite</h4>
                        <p style="margin: 0; font-size: 13px; color: #aaa;">TTS + Fast Timeline</p>
                    </div>
                    <div style="background: rgba(12, 24, 43, 0.85); border: 1px solid #00d4ff; border-radius: 14px; padding: 20px; text-align: center;">
                        <span style="font-size: 28px;">🛡️</span>
                        <h4 style="margin: 8px 0 4px 0; color: #00d4ff; font-weight: bold; font-size: 15px;">Account License</h4>
                        <p style="margin: 0; font-size: 13px; color: #aaa;">Verified Enterprise Access</p>
                    </div>
                    <div style="background: rgba(12, 24, 43, 0.85); border: 1px solid #00d4ff; border-radius: 14px; padding: 20px; text-align: center;">
                        <span style="font-size: 28px;">💬</span>
                        <h4 style="margin: 8px 0 4px 0; color: #00d4ff; font-weight: bold; font-size: 15px;">VIP Support</h4>
                        <p style="margin: 0; font-size: 12px; color: #aaa; line-height: 1.6;">
                            <a href='https://wa.me/923328140684' target='_blank' style='color:#25D366; text-decoration:none; font-weight:bold;'>WhatsApp: 0332-8140684</a><br>
                            <a href='https://www.instagram.com/maaz.rigs' target='_blank' style='color:#00d4ff; text-decoration:none;'>Insta: @maaz.rigs</a>
                        </p>
                    </div>
                </div>

                <div style="margin-top: 10px;">
                    <h3 style="color: #00d4ff; font-weight: bold; border-bottom: 2px solid rgba(0, 212, 255, 0.2); padding-bottom: 10px; margin-bottom: 18px; font-size: 18px;">🚀 AI Suite Ecosystem (Upcoming Modules)</h3>
                    <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(260px, 1fr)); gap: 16px;">
                        <div style="background: rgba(12, 24, 43, 0.7); border: 1px dashed rgba(0, 212, 255, 0.35); border-radius: 12px; padding: 18px;">
                            <div style="display: flex; justify-content: space-between; align-items: center;">
                                <h4 style="margin: 0; color: #fff; font-weight: bold; font-size: 15px;">🎬 AI Video Animator</h4>
                                <span style="background: #00d4ff; color: #000; font-size: 10px; font-weight: 800; padding: 3px 8px; border-radius: 6px;">COMING SOON</span>
                            </div>
                            <p style="font-size: 12px; color: #888; margin-top: 8px; line-height: 1.5;">Automated faceless story videos with 4K avatar rendering & lip-sync.</p>
                        </div>
                        <div style="background: rgba(12, 24, 43, 0.7); border: 1px dashed rgba(0, 212, 255, 0.35); border-radius: 12px; padding: 18px;">
                            <div style="display: flex; justify-content: space-between; align-items: center;">
                                <h4 style="margin: 0; color: #fff; font-weight: bold; font-size: 15px;">🖼️ AI Thumbnail Studio</h4>
                                <span style="background: #00d4ff; color: #000; font-size: 10px; font-weight: 800; padding: 3px 8px; border-radius: 6px;">COMING SOON</span>
                            </div>
                            <p style="font-size: 12px; color: #888; margin-top: 8px; line-height: 1.5;">High-CTR cinematic thumbnail visuals & avatar characters.</p>
                        </div>
                        <div style="background: rgba(12, 24, 43, 0.7); border: 1px dashed rgba(0, 212, 255, 0.35); border-radius: 12px; padding: 18px;">
                            <div style="display: flex; justify-content: space-between; align-items: center;">
                                <h4 style="margin: 0; color: #fff; font-weight: bold; font-size: 15px;">📜 AI Story & Hook Writer</h4>
                                <span style="background: #00d4ff; color: #000; font-size: 10px; font-weight: 800; padding: 3px 8px; border-radius: 6px;">COMING SOON</span>
                            </div>
                            <p style="font-size: 12px; color: #888; margin-top: 8px; line-height: 1.5;">Psychological suspense & emotional storytelling script engine.</p>
                        </div>
                        <div style="background: rgba(12, 24, 43, 0.7); border: 1px dashed rgba(0, 212, 255, 0.35); border-radius: 12px; padding: 18px;">
                            <div style="display: flex; justify-content: space-between; align-items: center;">
                                <h4 style="margin: 0; color: #fff; font-weight: bold; font-size: 15px;">✂️ Auto CapCut Timeline Sync</h4>
                                <span style="background: #00d4ff; color: #000; font-size: 10px; font-weight: 800; padding: 3px 8px; border-radius: 6px;">COMING SOON</span>
                            </div>
                            <p style="font-size: 12px; color: #888; margin-top: 8px; line-height: 1.5;">1-Click timeline cuts, dynamic zooms, and auto-synced subtitles.</p>
                        </div>
                    </div>
                </div>
            """)
'''

pro_tabs = '''
        with gr.TabItem("✂️ CapCut Splitter"):
            gr.Markdown("### 🎬 Fast Timeline Razor Tool")
            with gr.Row():
                with gr.Column():
                    cc_in = gr.Audio(label="1. Import Full Voiceover / Timeline Track", interactive=True)
                    with gr.Row():
                        cc_start_min = gr.Number(value=0, label="Start Min", precision=0)
                        cc_start_sec = gr.Number(value=0.0, label="Start Sec")
                    with gr.Row():
                        cc_end_min = gr.Number(value=0, label="End Min", precision=0)
                        cc_end_sec = gr.Number(value=15.0, label="End Sec (0 for Full)")
                    cc_btn = gr.Button("✂️ Fast Razor Cut & Export", variant="primary")
                with gr.Column():
                    cc_out = gr.Audio(label="Trimmed Timeline Clip Output")
                    cc_dl = gr.File(label="📥 Quick Download MP3")
                    cc_stat = gr.Textbox(label="Timeline Status", interactive=False)
            cc_btn.click(capcut_split_ui, inputs=[cc_in, cc_start_min, cc_start_sec, cc_end_min, cc_end_sec], outputs=[cc_out, cc_dl, cc_stat])

        with gr.TabItem("🎛️ 50+ FX Presets"):
            gr.Markdown("Studio mic styles, acoustic chambers, radio, robot aur cinema presets.")
            with gr.Row():
                with gr.Column():
                    fx_in = gr.Audio(label="1. Upload Voice Audio")
                    fx_preset = gr.Dropdown(choices=PRESETS_50, value=PRESETS_50[0], label="2. Choose 50+ FX Presets")
                    fx_int = gr.Slider(minimum=0.2, maximum=1.0, step=0.05, value=0.9, label="Effect Intensity")
                    fx_btn = gr.Button("⚡ Apply FX Preset", variant="primary")
                with gr.Column():
                    fx_out = gr.Audio(label="Mastered FX Output")
                    fx_dl = gr.File(label="📥 Quick Download MP3")
                    fx_stat = gr.Textbox(label="FX Status", interactive=False)
            fx_btn.click(apply_fx_preset_ui, inputs=[fx_in, fx_preset, fx_int], outputs=[fx_out, fx_dl, fx_stat])

        with gr.TabItem("🧹 Noise Cleaner"):
            gr.Markdown("Background fan noise, mic hiss aur room echo remove karein.")
            with gr.Row():
                with gr.Column():
                    c_in = gr.Audio(label="Upload Noisy Audio")
                    c_str = gr.Slider(minimum=0.1, maximum=1.0, step=0.05, value=0.85, label="Noise Removal Strength")
                    clean_btn = gr.Button("✨ Clean Audio", variant="primary")
                with gr.Column():
                    c_out = gr.Audio(label="Cleaned Audio")
                    c_dl = gr.File(label="📥 Quick Download MP3")
                    c_stat = gr.Textbox(label="Status", interactive=False)
            clean_btn.click(clean_audio_ui, inputs=[c_in, c_str], outputs=[c_out, c_dl, c_stat])
'''

with open('/content/voice-suite-colab/app.py', 'r', encoding='utf-8') as f:
    content = f.read()

content = tools_code + '\n' + content
content = re.sub(r'gr\.HTML\s*\(\s*["\'][\s\S]*?OmniVoice[\s\S]*?["\']\s*\)', '', content, flags=re.IGNORECASE)
content = re.sub(r'gr\.Markdown\s*\(\s*["\'][\s\S]*?OmniVoice[\s\S]*?["\']\s*\)', '', content, flags=re.IGNORECASE)
content = re.sub(r'gr\.Markdown\s*\(\s*["\'][\s\S]*?600\+[\s\S]*?["\']\s*\)', '', content, flags=re.IGNORECASE)
content = re.sub(r'gr\.Markdown\s*\(\s*["\'][\s\S]*?State-of-the-art[\s\S]*?["\']\s*\)', '', content, flags=re.IGNORECASE)
content = content.replace('title="OmniVoice Demo"', 'title="🎙️ MAAZ MALIK AI VOICE STUDIO"')

content = content.replace(
    'return audio_tuple, status, tmp_wav, c_srt, w_srt, s_srt',
    'tmp_mp3 = convert_to_mp3(tmp_wav)\n                return audio_tuple, status, tmp_mp3, c_srt, w_srt, s_srt'
)

content = content.replace('with gr.TabItem("Voice Clone"):', 'with gr.TabItem("🎙️ Voice Clone"):')
content = content.replace('with gr.TabItem("Voice Design"):', 'with gr.TabItem("🎨 Voice Design"):')

content = content.replace('with gr.Tabs():', dashboard_tab, 1)
content = content.replace('if __name__ == "__main__":', pro_tabs + '\nif __name__ == "__main__":')

if 'demo.launch(' in content:
    content = re.sub(r'demo\.launch\s*\([\s\S]*?\)', 'demo.launch(share=True, show_api=False, max_threads=40)', content)

with open('/content/voice-suite-colab/app.py', 'w', encoding='utf-8') as f:
    f.write(content)

# -------------------------------------------------------------
# 6) Realtime URL Interception & Clean Display
# -------------------------------------------------------------
import subprocess

os.chdir('/content/voice-suite-colab')
process = subprocess.Popen(
    ["python", "-u", "app.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

for line in iter(process.stdout.readline, ''):
    match = re.search(r'https://[a-zA-Z0-9-]+\.gradio\.live', line)
    if match:
        public_url = match.group(0)
        render_ui_card("ready", public_url=public_url)
        break

process.wait()
# Out:
#     <style>
#         @keyframes spin { 100% { transform: rotate(360deg); } }
#     </style>
#     <div style="font-family:-apple-system,BlinkMacSystemFont,'Segoe UI',Roboto,Helvetica,sans-serif;
#                 background:linear-gradient(145deg, #0a192f 0%, #060e1a 60%, #03070f 100%);
#                 border:1.5px solid rgba(0,212,255,0.5);border-radius:24px;padding:32px 38px;max-width:840px;
#                 box-shadow: 0 20px 60px rgba(0,0,0,0.7), 0 0 35px rgba(0,212,255,0.25), inset 0 1px 0 rgba(255,255,255,0.15);
#                 margin:12px 0;transform: perspective(1000px) rotateX(1deg);">
#
#         <div style="display:flex;justify-content:space-between;align-items:center;flex-wrap:wrap;gap:12px;margin-bottom:14px;">
#             <div style="font-size:1.7em;font-weight:900;color:#ffffff;letter-spacing:-0.5px;text-shadow: 0 2px 4px rgba(0,0,0,0.5);">
# ...
